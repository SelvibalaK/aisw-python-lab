# %%
# List Basics

# %%
# Creating a list

numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Mixed data types

student = ["Lee ", 87, True]
print(student)
# Out:
# ['Lee ', 87, True]

# %%
# Indexing

fruits = ["apple", "banana", "mango"]
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# mango

# %%
# Slicing

print(fruits[0:2])
# Out:
# ['apple', 'banana']
