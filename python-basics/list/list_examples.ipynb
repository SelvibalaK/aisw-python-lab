# %%
# List Basics

# %%
# Creating a list

numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Mixed data types

student = ["Lee ", 87, True]
print(student)
# Out:
# ['Lee ', 87, True]

# %%
# Indexing

fruits = ["apple", "banana", "mango"]
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# mango

# %%
# Slicing

print(fruits[0:2])
# Out:
# ['apple', 'banana']

# %%
# List operations and methods

# %%
# used to add an element to the list (no preferred location)

numbers = [10, 20, 30]
numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
# used to insert an element to the list ( preferred location - here it is second position of the list )

numbers.insert(1, 15)
print(numbers)
# Out:
# [10, 15, 20, 30, 40]

# %%
# to remove an certain element from the list 

numbers.remove(20)
print(numbers)
# Out:
# [10, 15, 30, 40]

# %%
# removes the last element of the list as of default 

numbers.pop()
print(numbers)
# Out:
# [10, 15, 30]

# %%
# in ascending order

numbers.sort()
print(numbers)
# Out:
# [10, 15, 30]

# %%
# in decesnding order

numbers.reverse()
print(numbers)
# Out:
# [30, 15, 10]

# %%
# Examples using List

# %%
# Student marks
marks = [78, 85, 90, 66]
average = sum(marks) / len(marks)
print("Average:", average)
# Out:
# Average: 79.75

# %%
# Shopping cart
cart = []
cart.append("Laptop")
cart.append("Mouse")
cart.append("Keyboard")
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard']

# %%
# Attendance check
students = ["A", "B", "C"]

if "A" in students:
    print("Present")
# Out:
# Present
