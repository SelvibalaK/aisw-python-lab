# %%
# Set Basics

# %%
numbers = {10, 20, 30, 20, 10}
print(numbers)
# Out:
# {10, 20, 30}

# %%
# Empty set
empty_set = set()
print(type(empty_set))
# Out:
# <class 'set'>

# %%
# {} is NOT an empty set , it’s a dictionary .
