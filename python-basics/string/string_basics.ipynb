# %%
# string basics

# %%
# single and double quotes string 

name = " Park "
college = 'Engineering '

# %%
# triple quotes string

bio = """ AI Engineer
Python Developer
Git User """

# %%
print(name)
print(college)
print(bio)
# Out:
#  Park
# Engineering
#  AI Engineer
# Python Developer
# Git User

# %%
# length of the string

print(len(name))
# Out:
# 6
