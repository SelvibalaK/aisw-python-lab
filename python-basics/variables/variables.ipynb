# %%
# Integer variable
age = 85
print(age)
# Out:
# 85

# %%
# Float variable
height = 6.1
print(height)
# Out:
# 6.1

# %%
# String variable
name = "Thor"
print(name)
# Out:
# Thor

# %%
# Boolean variable
is_student = True
print(is_student)
# Out:
# True

# %%
# Checking types
print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
